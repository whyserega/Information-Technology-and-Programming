# %% [markdown]
# # Лабораторная работа 2. Управление ходом выполнения программы
#
# **Выполнил Мелкумян Сергей ИНБ-б-о-26-2**

# %% [markdown]
# ## Задание

# %% [markdown]
# Необходимо вычислить значение выражения:
# $$Z=\frac{1}{1\cdot3}-\frac{X}{2\cdot4}+\frac{X^2}{3\cdot5}-\frac{X^3}{4\cdot6}+...$$
# Для каждой переменной необходимо вывести ее значение и тип.

# %% [markdown]
# ## Анализ выражения и определение переменных

# %% [markdown]
# Проанализируем выражение и определим переменные, которые потребуются для выполнения задания. Независимые переменные: $X$. Переменная, которая должна быть вычислена на основе независимых: $Z$.
#
# Следует обратить внимание, что в выражении неизвестное число слагаемых, поэтому необходимо ввести переменную $N$ для представления количества слагаемых.
#
# Обратите внимание, что знаки слагаемых чередуются, а степени числителя и множетели знаменателя привязаны к порядковому номеру слагаемого.

# %% [markdown]
# ## Вычисление выражение, печать результатов

# %% [markdown]
# Код для вычисления значения выражения $Z$:

# %%
X = 2
N = 10
Z = 0
for i in range(1, N+1):
  chisl = X**(i-1)
  znam = i * (i+1)
  if i%2==1:
    Z += chisl / znam
  else:
    Z -= chisl/znam
print(Z)
# Out:
# -2.573593073593073

# %% [markdown]
# Решите пример в соответствии с индивидуальным заданием

# %%
# Здесь код индивидуального задания...

# %% [markdown]
# ## Ответы на контрольные вопросы
#
# **1.** Переменная — это имя, которое используется для хранения значения в программе.
#
# **2.** Недопустимы `99bottles` — имя начинается с цифры, и `r&d` — содержит недопустимый символ `&`. Остальные имена допустимы.
#
# **3.** Нет. Python различает регистр букв, поэтому `Sales` и `sales` — разные переменные.
#
# **4.** Нет. Числу `72` нельзя присвоить значение, слева от `=` должно находиться имя переменной.
#
# **5.** На экран выведется `Значение равняется val`, потому что `'val'` в кавычках является текстом, а не именем переменной.
#
# **6.** `value1` — `int`, `value2` — `float`, `value3` — `float`, `value4` — `int`, `value5` — `str`.
#
# **7.** На экран выведется `0`, потому что сначала `my_value` получает значение `99`, а затем ему присваивается `0`.
#
# **8.** Можно записать так:
# ```python
# for x in range(6):
#     print('Обожаю эту программу!')
# ```
#
# **9.** Выведутся числа от `0` до `5`:
# ```text
# 0
# 1
# 2
# 3
# 4
# 5
# ```
#
# **10.** Выведутся числа от `2` до `5`:
# ```text
# 2
# 3
# 4
# 5
# ```
#
# **11.** Выведутся числа `0, 100, 200, 300, 400, 500`.
#
# **12.** Выведутся числа `10, 9, 8, 7, 6`.
#
# **13.** Накопитель — переменная, в которой постепенно накапливается результат вычислений.
#
# **14.** Да. Накопитель нужно заранее инициализировать, обычно нулём.
#
# **15.** Программа складывает числа от `1` до `5`. В результате получается `15`.
#
# **16.** `number1` сначала равен `10`, затем к нему прибавляется `5`. Выведется:
# ```text
# 15 5
# ```
#
# **17.** С использованием расширенных операторов присваивания:
# ```python
# quantity += 1
# days_left -= 5
# price *= 10
# price /= 2
# ```
#
# **18.**
# ```python
# surname = input('Введите фамилию клиента: ')
# ```
#
# **19.**
# ```python
# sales = input('Введите объем продаж за неделю: ')
# ```
#
# **20.** Бесконечный цикл — это цикл, который не заканчивается самостоятельно. Например:
# ```python
# while True:
#     print('Цикл продолжается')
# ```
